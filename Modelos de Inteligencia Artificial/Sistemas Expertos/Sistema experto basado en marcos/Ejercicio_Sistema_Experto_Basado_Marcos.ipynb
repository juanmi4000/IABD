# %%
class Enfermedad:
    def __init__(self, nombre, sintomas, tratamiento):
        self.nombre = nombre
        self.sintomas = sintomas
        self.tratamiento = tratamiento

    def __str__(self):
        return f" Enfermedad: {self.nombre}\n Síntomas: {', '.join(self.sintomas)}\n Tratamiento: {self.tratamiento}"

# Creación de la Base de Conocimiento

gripe = Enfermedad("Gripe", ["fiebre", "tos", "dolor de garganta"], "Reposo y líquidos")
resfriado_comun = Enfermedad("Resfriado común", ["fiebre", "tos", "dolor de cabeza", "dolor muscular"], "Beber mucho líquido y reposo.")
covid_19 = Enfermedad("Covid-19", ["fiebre", "tos", "dificultad al respirar", "perdida de olfato y gusto"], "Realizar prueba de antígenos.")
neumonia = Enfermedad("Neumonía", ["fiebre", "dificultad para respirar", "tos fuerte"], "Antibióticos y hospitalización si es grave")
migraña = Enfermedad("Migraña", ["dolor de cabeza", "náuseas", "sensibilidad a la luz"], "Analgésicos y descanso")
alergia = Enfermedad("Alergia", ["estornudos", "congestión nasal", "ojos llorosos"], "Ponerse mascarilla y alejarse de lo que le produzca alergia.")

# Base de conocimientos estructurada como un MARCO
base_conocimiento = {
    "gripe": gripe,
    "resfriado_comun": resfriado_comun,
    "covid19": covid_19,
    "neumonia": neumonia,
    "migraña": migraña,
    "alergia": alergia
}

print("🔍 **SISTEMA EXPERTO DE DIAGNÓSTICO DE ENFERMEDADES** 🔍\n")
print("📌 Selecciona una enfermedad:")
for indice, enfermedad in enumerate(base_conocimiento.values()):
  print(f"{indice + 1}. {enfermedad.nombre}")

opcion = input("\nIngrese el número del problema: ").strip()

mostrado = False

for indice, enfermedad in enumerate(base_conocimiento.values()):
  if str(indice + 1) == opcion:
    print(enfermedad)
    mostrado = True

if not mostrado:
  print("No se reconoce esa opción")
# Out:
# 🔍 **SISTEMA EXPERTO DE DIAGNÓSTICO DE ENFERMEDADES** 🔍
#
# 📌 Selecciona una enfermedad:
# 1. Gripe
# 2. Resfriado común
# 3. Covid-19
# 4. Neumonía
# 5. Migraña
# 6. Alergia
#
# Ingrese el número del problema: 5
#  Enfermedad: Migraña
#  Síntomas: dolor de cabeza, náuseas, sensibilidad a la luz
#  Tratamiento: Analgésicos y descanso
